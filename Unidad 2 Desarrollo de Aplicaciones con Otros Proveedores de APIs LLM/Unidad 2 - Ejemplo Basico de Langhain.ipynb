# %% [markdown]
# ## Importar librerias

# %%
from langchain_openai import OpenAI
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Configuración del Cliente de OpenAI con Variables de Entorno + Langchain

# %%
# Cargar variables del archivo .env
load_dotenv()

# Obtener la API key desde las variables de entorno
openai_api_key = os.getenv("OPENAI_API_KEY")

# Crear la instancia del modelo con la API key
llm = OpenAI(openai_api_key=openai_api_key)

# %% [markdown]
# ## Uso de la clase LLM para interactuar con el modelo

# %%
# Hacer una consulta al modelo
response = llm.invoke("Cuántos goles ha marcado Messi en toda su carrera?")
response
# Out:
# '\n\nSegún datos oficiales, Lionel Messi ha marcado un total de 741 goles en toda su carrera hasta el momento (actualizado al 1 de julio de 2021). De estos goles, 672 han sido con el FC Barcelona y 69 con la selección argentina.'
